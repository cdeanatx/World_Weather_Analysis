# %%
# import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitudes and longitudes
lats = np.random.uniform(-90, 90, size=1500)
lngs = np.random.uniform(-180, 180, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the lats and lngs to a list
coords = list(lat_lngs)

# %%
# Use the citipy module to determine city based on lat and lng
from citipy import citipy

# %%
# Create a list for holding the cities nearest the randomly generated coords
cities = []

for coord in coords:
    city = citipy.nearest_city(coord[0], coord[1]).city_name

    # Only add the city if it's not already in the list
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 600

# %%
# Load dependency and key for upcoming API call
import requests
from datetime import datetime
from config import weather_api_key

# %%
# Set up initial URL and counters
url = 'http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=' + weather_api_key
# data = requests.get(query_url).json()
# data
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through each city in the cities array and pull data using API
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0) & (i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL for each city
    query_url = url + '&q=' + city.replace(' ', '+')

    #Log the URL, record, and set numbers and the city.
    print(f'Processing Record {record_count} of Set {set_count} | {city}')
    
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse out the needed data
        city_weather = requests.get(query_url).json()
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        # Convert time to ISO standard
        city_date = datetime.utcfromtimestamp(city_weather['dt']).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city data
        city_data.append({
                        'City': city.title(),
                        'Lat': city_lat,
                        'Lng': city_lng,
                        'Max Temp': city_max_temp,
                        'Humidity': city_humidity,
                        'Clouds': city_clouds,
                        'Wind': city_wind,
                        'Country': city_country,
                        'Date': city_date
        })
    except:
        print(city + ' not found. Skipping...')
        continue

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | kuching
# Processing Record 2 of Set 1 | sattahip
# Processing Record 3 of Set 1 | charters towers
# Processing Record 4 of Set 1 | bluff
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | la plata
# Processing Record 7 of Set 1 | kapaa
# Processing Record 8 of Set 1 | vaini
# Processing Record 9 of Set 1 | yantai
# Processing Record 10 of Set 1 | illoqqortoormiut
# illoqqortoormiut not found. Skipping...
# Processing Record 11 of Set 1 | port macquarie
# Processing Record 12 of Set 1 | hermanus
# Processing Record 13 of Set 1 | belushya guba
# belushya guba not found. Skipping...
# Processing Record 14 of Set 1 | ilulissat
# Processing Record 15 of Set 1 | tiksi
# Processing Record 16 of Set 1 | san carlos de bariloche
# Processing Record 17 of Set 1 | jamestown
# Processing Record 18 of Set 1 | moerai
# Processing Record 19 of Set 1 | otane
# Processing Record 20 of Set 1 | karratha
# Processing Record 21 of Set 1 | busselton
# Processing Record 22 of Set 1 | east london
# Processing Record 23 of Set 1 | sredec
# sredec not found. Skipping...
# Processing Record 24 of Set 1 | mackay
# Processing Record 25 of Set 1 | avarua
# Processing Record 26 of Set 1 | punta arenas
# Processing Record 27 of Set 1 | surt
# Processing Record 28 of Set 1 | amderma
# amderma not found. Skipping...
# Processing Record 29 of Set 1 | arraial do cabo
# Processing Record 30 of Set 1 | tumarbong
# Processing Record 31 of Set 1 | port alfred
# Processing Record 32 of Set 1 | chokurdakh
# Processing Record 33 of Set 1 | verkhovazhye
# Processing Record 34 of Set 1 | mataura
# Processing Record 35 of Set 1 | tasiilaq
# Processing Record 36 of Set 1 | caluquembe
# Processing Record 37 of Set 1 | rikitea
# Processing Record 38 of Set 1 | bud
# Processing Record 39 of Set 1 | cape town
# Processing Record 40 of Set 1 | colan
# Processing Record 41 of Set 1 | at-bashi
# Processing Record 42 of Set 1 | taolanaro
# taolanaro not found. Skipping...
# Processing Record 43 of Set 1 | glomfjord
# Processing Record 44 of Set 1 | hithadhoo
# Processing Record 45 of Set 1 | bambous virieux
# Processing Record 46 of Set 1 | mar del plata
# Processing Record 47 of Set 1 | bredasdorp
# Processing Record 48 of Set 1 | kislovodsk
# Processing Record 49 of Set 1 | albany
# Processing Record 50 of Set 1 | atuona
# Processing Record 1 of Set 2 | georgetown
# Processing Record 2 of Set 2 | tuktoyaktuk
# Processing Record 3 of Set 2 | jonesboro
# Processing Record 4 of Set 2 | pampa
# Processing Record 5 of Set 2 | tommot
# Processing Record 6 of Set 2 | castro
# Processing Record 7 of Set 2 | sembakung
# Processing Record 8 of Set 2 | oranzherei
# Processing Record 9 of Set 2 | nemuro
# Processing Record 10 of Set 2 | clyde river
# Processing Record 11 of Set 2 | marawi
# Processing Record 12 of Set 2 | san benito
# Processing Record 13 of Set 2 | vila franca do campo
# Processing Record 14 of Set 2 | katsuura
# Processing Record 15 of Set 2 | nalut
# Processing Record 16 of Set 2 | cururupu
# Processing Record 17 of Set 2 | karkaralinsk
# karkaralinsk not found. Skipping...
# Processing Record 18 of Set 2 | semey
# Processing Record 19 of Set 2 | leningradskiy
# Processing Record 20 of Set 2 | patacamaya
# Processing Record 21 of Set 2 | klaksvik
# Processing Record 22 of Set 2 | hobart
# Processing Record 23 of Set 2 | otradnoye
# Processing Record 24 of Set 2 | toliary
# toliary not found. Skipping...
# Processing Record 25 of Set 2 | carnarvon
# Processing Record 26 of Set 2 | cayenne
# Processing Record 27 of Set 2 | kampot
# Processing Record 28 of Set 2 | amahai
# Processing Record 29 of Set 2 | nantucket
# Processing Record 30 of Set 2 | waitara
# Processing Record 31 of Set 2 | cabo san lucas
# Processing Record 32 of Set 2 | kapit
# Processing Record 33 of Set 2 | keuruu
# Processing Record 34 of Set 2 | luderitz
# Processing Record 35 of Set 2 | vila velha
# Processing Record 36 of Set 2 | sabang
# Processing Record 37 of Set 2 | berlevag
# Processing Record 38 of Set 2 | pasca
# Processing Record 39 of Set 2 | ishigaki
# Processing Record 40 of Set 2 | hengyang
# Processing Record 41 of Set 2 | hilo
# Processing Record 42 of Set 2 | demirci
# Processing Record 43 of Set 2 | poum
# Processing Record 44 of Set 2 | puerto ayora
# Processing Record 45 of Set 2 | karaul
# karaul not found. Skipping...
# Processing Record 46 of Set 2 | umm kaddadah
# Processing Record 47 of Set 2 | subacius
# subacius not found. Skipping...
# Processing Record 48 of Set 2 | dikson
# Processing Record 49 of Set 2 | cherskiy
# Processing Record 50 of Set 2 | butaritari
# Processing Record 1 of Set 3 | komsomolskiy
# Processing Record 2 of Set 3 | yellowknife
# Processing Record 3 of Set 3 | seydi
# Processing Record 4 of Set 3 | haines junction
# Processing Record 5 of Set 3 | teguldet
# Processing Record 6 of Set 3 | borujan
# borujan not found. Skipping...
# Processing Record 7 of Set 3 | hasaki
# Processing Record 8 of Set 3 | guerrero negro
# Processing Record 9 of Set 3 | challapalle
# Processing Record 10 of Set 3 | nikolskoye
# Processing Record 11 of Set 3 | toila
# Processing Record 12 of Set 3 | posse
# Processing Record 13 of Set 3 | ponta do sol
# Processing Record 14 of Set 3 | marsh harbour
# Processing Record 15 of Set 3 | korla
# Processing Record 16 of Set 3 | barentsburg
# barentsburg not found. Skipping...
# Processing Record 17 of Set 3 | mount isa
# Processing Record 18 of Set 3 | bantou
# Processing Record 19 of Set 3 | tigzirt
# Processing Record 20 of Set 3 | torbay
# Processing Record 21 of Set 3 | saskylakh
# Processing Record 22 of Set 3 | vaitupu
# vaitupu not found. Skipping...
# Processing Record 23 of Set 3 | tautira
# Processing Record 24 of Set 3 | khatanga
# Processing Record 25 of Set 3 | concarneau
# Processing Record 26 of Set 3 | luang prabang
# Processing Record 27 of Set 3 | muros
# Processing Record 28 of Set 3 | tual
# Processing Record 29 of Set 3 | airai
# Processing Record 30 of Set 3 | sangmelima
# Processing Record 31 of Set 3 | kavieng
# Processing Record 32 of Set 3 | carballo
# Processing Record 33 of Set 3 | tumannyy
# tumannyy not found. Skipping...
# Processing Record 34 of Set 3 | lincoln
# Processing Record 35 of Set 3 | pisco
# Processing Record 36 of Set 3 | nizhneyansk
# nizhneyansk not found. Skipping...
# Processing Record 37 of Set 3 | mullaitivu
# mullaitivu not found. Skipping...
# Processing Record 38 of Set 3 | cockburn town
# Processing Record 39 of Set 3 | lorengau
# Processing Record 40 of Set 3 | makokou
# Processing Record 41 of Set 3 | celestun
# Processing Record 42 of Set 3 | kodiak
# Processing Record 43 of Set 3 | puri
# Processing Record 44 of Set 3 | namie
# Processing Record 45 of Set 3 | bara
# Processing Record 46 of Set 3 | bengkulu
# Processing Record 47 of Set 3 | college
# Processing Record 48 of Set 3 | nowy dwor gdanski
# Processing Record 49 of Set 3 | flinders
# Processing Record 50 of Set 3 | ramon castilla
# Processing Record 1 of Set 4 | salalah
# Processing Record 2 of Set 4 | saleaula
# saleaula not found. Skipping...
# Processing Record 3 of Set 4 | grand river south east
# grand river south east not found. Skipping...
# Processing Record 4 of Set 4 | saint george
# Processing Record 5 of Set 4 | hofn
# Processing Record 6 of Set 4 | barrow
# Processing Record 7 of Set 4 | zhigansk
# Processing Record 8 of Set 4 | benguela
# Processing Record 9 of Set 4 | marquette
# Processing Record 10 of Set 4 | kyabram
# Processing Record 11 of Set 4 | manjakandriana
# Processing Record 12 of Set 4 | san quintin
# Processing Record 13 of Set 4 | luena
# Processing Record 14 of Set 4 | muzaffarabad
# Processing Record 15 of Set 4 | nome
# Processing Record 16 of Set 4 | new norfolk
# Processing Record 17 of Set 4 | kungurtug
# Processing Record 18 of Set 4 | kamenskoye
# kamenskoye not found. Skipping...
# Processing Record 19 of Set 4 | batagay
# Processing Record 20 of Set 4 | thompson
# Processing Record 21 of Set 4 | north shore
# Processing Record 22 of Set 4 | comodoro rivadavia
# Processing Record 23 of Set 4 | samusu
# samusu not found. Skipping...
# Processing Record 24 of Set 4 | paradwip
# paradwip not found. Skipping...
# Processing Record 25 of Set 4 | kangasala
# Processing Record 26 of Set 4 | padang
# Processing Record 27 of Set 4 | mezen
# Processing Record 28 of Set 4 | nelson bay
# Processing Record 29 of Set 4 | solvychegodsk
# Processing Record 30 of Set 4 | weyburn
# Processing Record 31 of Set 4 | sawakin
# Processing Record 32 of Set 4 | deoband
# Processing Record 33 of Set 4 | chinhoyi
# Processing Record 34 of Set 4 | mabaruma
# Processing Record 35 of Set 4 | manzil salim
# Processing Record 36 of Set 4 | san jose
# Processing Record 37 of Set 4 | ostersund
# Processing Record 38 of Set 4 | dali
# Processing Record 39 of Set 4 | cacoal
# Processing Record 40 of Set 4 | bereda
# Processing Record 41 of Set 4 | raga
# Processing Record 42 of Set 4 | asayita
# asayita not found. Skipping...
# Processing Record 43 of Set 4 | narsaq
# Processing Record 44 of Set 4 | avera
# Processing Record 45 of Set 4 | attawapiskat
# attawapiskat not found. Skipping...
# Processing Record 46 of Set 4 | elizabeth city
# Processing Record 47 of Set 4 | port hardy
# Processing Record 48 of Set 4 | raudeberg
# Processing Record 49 of Set 4 | lanja
# Processing Record 50 of Set 4 | kasempa
# Processing Record 1 of Set 5 | taloqan
# Processing Record 2 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 3 of Set 5 | chicama
# Processing Record 4 of Set 5 | zeya
# Processing Record 5 of Set 5 | geraldton
# Processing Record 6 of Set 5 | tsienyane
# tsienyane not found. Skipping...
# Processing Record 7 of Set 5 | san bartolome de tirajana
# Processing Record 8 of Set 5 | mahebourg
# Processing Record 9 of Set 5 | natal
# Processing Record 10 of Set 5 | oussouye
# Processing Record 11 of Set 5 | norman wells
# Processing Record 12 of Set 5 | aflu
# aflu not found. Skipping...
# Processing Record 13 of Set 5 | iroquois falls
# Processing Record 14 of Set 5 | kuruman
# Processing Record 15 of Set 5 | deputatskiy
# Processing Record 16 of Set 5 | vanimo
# Processing Record 17 of Set 5 | hualmay
# Processing Record 18 of Set 5 | huarmey
# Processing Record 19 of Set 5 | kaman
# Processing Record 20 of Set 5 | buchanan
# Processing Record 21 of Set 5 | nuuk
# Processing Record 22 of Set 5 | yemtsa
# Processing Record 23 of Set 5 | pacific grove
# Processing Record 24 of Set 5 | ulaangom
# Processing Record 25 of Set 5 | bougouni
# Processing Record 26 of Set 5 | basco
# Processing Record 27 of Set 5 | bethel
# Processing Record 28 of Set 5 | ribeira grande
# Processing Record 29 of Set 5 | chuy
# Processing Record 30 of Set 5 | namibe
# Processing Record 31 of Set 5 | avondale
# Processing Record 32 of Set 5 | yarada
# Processing Record 33 of Set 5 | sao filipe
# Processing Record 34 of Set 5 | khasan
# Processing Record 35 of Set 5 | yumen
# Processing Record 36 of Set 5 | saryagash
# Processing Record 37 of Set 5 | kirovskiy
# Processing Record 38 of Set 5 | xining
# Processing Record 39 of Set 5 | bejar
# Processing Record 40 of Set 5 | atar
# Processing Record 41 of Set 5 | milos
# Processing Record 42 of Set 5 | ketchenery
# ketchenery not found. Skipping...
# Processing Record 43 of Set 5 | port lincoln
# Processing Record 44 of Set 5 | sandwick
# Processing Record 45 of Set 5 | chumikan
# Processing Record 46 of Set 5 | palabuhanratu
# palabuhanratu not found. Skipping...
# Processing Record 47 of Set 5 | faanui
# Processing Record 48 of Set 5 | sitka
# Processing Record 49 of Set 5 | isangel
# Processing Record 50 of Set 5 | jiuquan
# Processing Record 1 of Set 6 | port elizabeth
# Processing Record 2 of Set 6 | esperance
# Processing Record 3 of Set 6 | tabuk
# Processing Record 4 of Set 6 | saldanha
# Processing Record 5 of Set 6 | victoria
# Processing Record 6 of Set 6 | lasa
# Processing Record 7 of Set 6 | brae
# Processing Record 8 of Set 6 | coihaique
# Processing Record 9 of Set 6 | honiara
# Processing Record 10 of Set 6 | cidreira
# Processing Record 11 of Set 6 | margate
# Processing Record 12 of Set 6 | okhotsk
# Processing Record 13 of Set 6 | road town
# Processing Record 14 of Set 6 | mount gambier
# Processing Record 15 of Set 6 | olafsvik
# Processing Record 16 of Set 6 | urumqi
# Processing Record 17 of Set 6 | zaozerne
# Processing Record 18 of Set 6 | lar gerd
# lar gerd not found. Skipping...
# Processing Record 19 of Set 6 | palmer
# Processing Record 20 of Set 6 | kayerkan
# Processing Record 21 of Set 6 | owando
# Processing Record 22 of Set 6 | moree
# Processing Record 23 of Set 6 | kaitangata
# Processing Record 24 of Set 6 | kulhudhuffushi
# Processing Record 25 of Set 6 | lavrentiya
# Processing Record 26 of Set 6 | qom
# Processing Record 27 of Set 6 | laguna
# Processing Record 28 of Set 6 | viligili
# viligili not found. Skipping...
# Processing Record 29 of Set 6 | san patricio
# Processing Record 30 of Set 6 | alofi
# Processing Record 31 of Set 6 | lisala
# Processing Record 32 of Set 6 | alvaraes
# Processing Record 33 of Set 6 | ayagoz
# Processing Record 34 of Set 6 | touros
# Processing Record 35 of Set 6 | el campo
# Processing Record 36 of Set 6 | maun
# Processing Record 37 of Set 6 | kahului
# Processing Record 38 of Set 6 | katobu
# Processing Record 39 of Set 6 | farmington
# Processing Record 40 of Set 6 | pontianak
# Processing Record 41 of Set 6 | troitsko-pechorsk
# Processing Record 42 of Set 6 | sorland
# Processing Record 43 of Set 6 | kushima
# Processing Record 44 of Set 6 | solnechnyy
# Processing Record 45 of Set 6 | pekan
# Processing Record 46 of Set 6 | mendeleyevo
# Processing Record 47 of Set 6 | grand gaube
# Processing Record 48 of Set 6 | muncar
# Processing Record 49 of Set 6 | bolungarvik
# bolungarvik not found. Skipping...
# Processing Record 50 of Set 6 | san cristobal
# Processing Record 1 of Set 7 | port-cartier
# Processing Record 2 of Set 7 | collie
# Processing Record 3 of Set 7 | aksarka
# Processing Record 4 of Set 7 | karoi
# Processing Record 5 of Set 7 | parian dakula
# Processing Record 6 of Set 7 | upernavik
# Processing Record 7 of Set 7 | rome
# Processing Record 8 of Set 7 | pudozh
# Processing Record 9 of Set 7 | panaba
# Processing Record 10 of Set 7 | ouegoa
# Processing Record 11 of Set 7 | longyearbyen
# Processing Record 12 of Set 7 | qaanaaq
# Processing Record 13 of Set 7 | massaguet
# Processing Record 14 of Set 7 | sept-iles
# Processing Record 15 of Set 7 | yar-sale
# Processing Record 16 of Set 7 | lumberton
# Processing Record 17 of Set 7 | pevek
# Processing Record 18 of Set 7 | boende
# Processing Record 19 of Set 7 | mehamn
# Processing Record 20 of Set 7 | irkutsk
# Processing Record 21 of Set 7 | saint-philippe
# Processing Record 22 of Set 7 | lagos
# Processing Record 23 of Set 7 | pangnirtung
# Processing Record 24 of Set 7 | ostrovnoy
# Processing Record 25 of Set 7 | severo-kurilsk
# Processing Record 26 of Set 7 | adre
# Processing Record 27 of Set 7 | saint-leu
# Processing Record 28 of Set 7 | bataipora
# Processing Record 29 of Set 7 | fairbanks
# Processing Record 30 of Set 7 | ndele
# Processing Record 31 of Set 7 | umm lajj
# Processing Record 32 of Set 7 | kavaratti
# Processing Record 33 of Set 7 | jinchang
# Processing Record 34 of Set 7 | bathsheba
# Processing Record 35 of Set 7 | inhambane
# Processing Record 36 of Set 7 | fevralsk
# fevralsk not found. Skipping...
# Processing Record 37 of Set 7 | ayan
# Processing Record 38 of Set 7 | vallenar
# Processing Record 39 of Set 7 | santa marta
# Processing Record 40 of Set 7 | azrow
# azrow not found. Skipping...
# Processing Record 41 of Set 7 | provideniya
# Processing Record 42 of Set 7 | the valley
# Processing Record 43 of Set 7 | pangai
# Processing Record 44 of Set 7 | qaqortoq
# Processing Record 45 of Set 7 | khorramshahr
# Processing Record 46 of Set 7 | mys shmidta
# mys shmidta not found. Skipping...
# Processing Record 47 of Set 7 | talnakh
# Processing Record 48 of Set 7 | cochrane
# Processing Record 49 of Set 7 | itaborai
# Processing Record 50 of Set 7 | barcelos
# Processing Record 1 of Set 8 | partizanskoye
# Processing Record 2 of Set 8 | beyla
# Processing Record 3 of Set 8 | bay roberts
# Processing Record 4 of Set 8 | iqaluit
# Processing Record 5 of Set 8 | svetlyy
# Processing Record 6 of Set 8 | tarquinia
# Processing Record 7 of Set 8 | yangambi
# Processing Record 8 of Set 8 | port hedland
# Processing Record 9 of Set 8 | zarinsk
# Processing Record 10 of Set 8 | feodosiya
# Processing Record 11 of Set 8 | pleasanton
# Processing Record 12 of Set 8 | mayo
# Processing Record 13 of Set 8 | codrington
# Processing Record 14 of Set 8 | roura
# Processing Record 15 of Set 8 | diffa
# Processing Record 16 of Set 8 | russell
# Processing Record 17 of Set 8 | chiredzi
# Processing Record 18 of Set 8 | samarai
# Processing Record 19 of Set 8 | wewak
# Processing Record 20 of Set 8 | les cayes
# Processing Record 21 of Set 8 | paka
# Processing Record 22 of Set 8 | manicore
# Processing Record 23 of Set 8 | afantou
# Processing Record 24 of Set 8 | kangaatsiaq
# Processing Record 25 of Set 8 | north platte
# Processing Record 26 of Set 8 | marcona
# marcona not found. Skipping...
# Processing Record 27 of Set 8 | itarema
# Processing Record 28 of Set 8 | faya
# Processing Record 29 of Set 8 | alice springs
# Processing Record 30 of Set 8 | balaguer
# Processing Record 31 of Set 8 | khash
# Processing Record 32 of Set 8 | dongli
# Processing Record 33 of Set 8 | ishinomaki
# Processing Record 34 of Set 8 | imbituba
# Processing Record 35 of Set 8 | chebsara
# Processing Record 36 of Set 8 | tuatapere
# Processing Record 37 of Set 8 | tsihombe
# tsihombe not found. Skipping...
# Processing Record 38 of Set 8 | pundaguitan
# Processing Record 39 of Set 8 | bijar
# Processing Record 40 of Set 8 | tezu
# Processing Record 41 of Set 8 | boa vista
# Processing Record 42 of Set 8 | ustka
# Processing Record 43 of Set 8 | kindu
# Processing Record 44 of Set 8 | abalak
# Processing Record 45 of Set 8 | broome
# Processing Record 46 of Set 8 | tilichiki
# Processing Record 47 of Set 8 | muroto
# Processing Record 48 of Set 8 | tierranueva
# Processing Record 49 of Set 8 | inveraray
# inveraray not found. Skipping...
# Processing Record 50 of Set 8 | culiacan
# Processing Record 1 of Set 9 | zyryanka
# Processing Record 2 of Set 9 | neuquen
# Processing Record 3 of Set 9 | hendijan
# hendijan not found. Skipping...
# Processing Record 4 of Set 9 | cartagena
# Processing Record 5 of Set 9 | naze
# Processing Record 6 of Set 9 | neyshabur
# Processing Record 7 of Set 9 | vao
# Processing Record 8 of Set 9 | vardo
# Processing Record 9 of Set 9 | manta
# Processing Record 10 of Set 9 | udachnyy
# Processing Record 11 of Set 9 | timmins
# Processing Record 12 of Set 9 | kodinsk
# Processing Record 13 of Set 9 | mangrol
# Processing Record 14 of Set 9 | coihueco
# Processing Record 15 of Set 9 | bismil
# Processing Record 16 of Set 9 | manga
# Processing Record 17 of Set 9 | erzin
# Processing Record 18 of Set 9 | parkes
# Processing Record 19 of Set 9 | baherden
# Processing Record 20 of Set 9 | baboua
# baboua not found. Skipping...
# Processing Record 21 of Set 9 | sinnamary
# Processing Record 22 of Set 9 | pimentel
# Processing Record 23 of Set 9 | tarakan
# Processing Record 24 of Set 9 | lebu
# Processing Record 25 of Set 9 | makakilo city
# Processing Record 26 of Set 9 | blagoveshchensk
# Processing Record 27 of Set 9 | sulzbach-rosenberg
# Processing Record 28 of Set 9 | paita
# Processing Record 29 of Set 9 | boyabat
# Processing Record 30 of Set 9 | north las vegas
# Processing Record 31 of Set 9 | muscat
# Processing Record 32 of Set 9 | tabiauea
# tabiauea not found. Skipping...
# Processing Record 33 of Set 9 | hamilton
# Processing Record 34 of Set 9 | gamba
# Processing Record 35 of Set 9 | boguchany
# Processing Record 36 of Set 9 | labutta
# labutta not found. Skipping...
# Processing Record 37 of Set 9 | kisangani
# Processing Record 38 of Set 9 | romny
# Processing Record 39 of Set 9 | dingle
# Processing Record 40 of Set 9 | manokwari
# Processing Record 41 of Set 9 | gusinoye ozero
# Processing Record 42 of Set 9 | boo
# Processing Record 43 of Set 9 | goderich
# Processing Record 44 of Set 9 | saint-joseph
# Processing Record 45 of Set 9 | constitucion
# Processing Record 46 of Set 9 | kaka
# Processing Record 47 of Set 9 | te anau
# Processing Record 48 of Set 9 | hearst
# Processing Record 49 of Set 9 | morondava
# Processing Record 50 of Set 9 | madang
# Processing Record 1 of Set 10 | jalcocotan
# Processing Record 2 of Set 10 | kiama
# Processing Record 3 of Set 10 | shingu
# Processing Record 4 of Set 10 | sioux lookout
# Processing Record 5 of Set 10 | mildura
# Processing Record 6 of Set 10 | srednekolymsk
# Processing Record 7 of Set 10 | christchurch
# Processing Record 8 of Set 10 | ambilobe
# Processing Record 9 of Set 10 | hobyo
# Processing Record 10 of Set 10 | rocha
# Processing Record 11 of Set 10 | rungata
# rungata not found. Skipping...
# Processing Record 12 of Set 10 | lima
# Processing Record 13 of Set 10 | stity
# Processing Record 14 of Set 10 | sicuani
# Processing Record 15 of Set 10 | bahir dar
# Processing Record 16 of Set 10 | nara
# Processing Record 17 of Set 10 | wawa
# Processing Record 18 of Set 10 | gulshat
# gulshat not found. Skipping...
# Processing Record 19 of Set 10 | seoul
# Processing Record 20 of Set 10 | chapais
# Processing Record 21 of Set 10 | ust-maya
# Processing Record 22 of Set 10 | jalu
# Processing Record 23 of Set 10 | kericho
# Processing Record 24 of Set 10 | portland
# Processing Record 25 of Set 10 | tura
# Processing Record 26 of Set 10 | salta
# Processing Record 27 of Set 10 | iskitim
# Processing Record 28 of Set 10 | boyolangu
# Processing Record 29 of Set 10 | mae hong son
# Processing Record 30 of Set 10 | seymchan
# Processing Record 31 of Set 10 | vilyuysk
# Processing Record 32 of Set 10 | lompoc
# Processing Record 33 of Set 10 | qabis
# qabis not found. Skipping...
# Processing Record 34 of Set 10 | kitimat
# Processing Record 35 of Set 10 | jimeta
# Processing Record 36 of Set 10 | la ronge
# Processing Record 37 of Set 10 | antalya
# Processing Record 38 of Set 10 | kloulklubed
# Processing Record 39 of Set 10 | vostok
# Processing Record 40 of Set 10 | tuggurt
# tuggurt not found. Skipping...
# Processing Record 41 of Set 10 | taltal
# Processing Record 42 of Set 10 | koslan
# Processing Record 43 of Set 10 | gurgan
# gurgan not found. Skipping...
# Processing Record 44 of Set 10 | bijie
# Processing Record 45 of Set 10 | voyvozh
# Processing Record 46 of Set 10 | talah
# talah not found. Skipping...
# Processing Record 47 of Set 10 | yerbogachen
# Processing Record 48 of Set 10 | dhidhdhoo
# Processing Record 49 of Set 10 | manyana
# Processing Record 50 of Set 10 | lakatoro
# Processing Record 1 of Set 11 | bayonet point
# Processing Record 2 of Set 11 | fortuna
# Processing Record 3 of Set 11 | asau
# Processing Record 4 of Set 11 | kultuk
# Processing Record 5 of Set 11 | half moon bay
# Processing Record 6 of Set 11 | areosa
# Processing Record 7 of Set 11 | satitoa
# satitoa not found. Skipping...
# Processing Record 8 of Set 11 | angoram
# Processing Record 9 of Set 11 | were ilu
# Processing Record 10 of Set 11 | okha
# Processing Record 11 of Set 11 | mitsamiouli
# Processing Record 12 of Set 11 | superior
# Processing Record 13 of Set 11 | tromso
# Processing Record 14 of Set 11 | damietta
# Processing Record 15 of Set 11 | anan
# Processing Record 16 of Set 11 | tubig indangan
# tubig indangan not found. Skipping...
# Processing Record 17 of Set 11 | miyako
# Processing Record 18 of Set 11 | pangkalanbuun
# Processing Record 19 of Set 11 | plaeng yao
# Processing Record 20 of Set 11 | san juan del sur
# Processing Record 21 of Set 11 | bilokurakyne
# Processing Record 22 of Set 11 | north bend
# Processing Record 23 of Set 11 | whitianga
# Processing Record 24 of Set 11 | voh
# Processing Record 25 of Set 11 | thaton
# Processing Record 26 of Set 11 | saint-pierre
# Processing Record 27 of Set 11 | quatre cocos
# Processing Record 28 of Set 11 | burica
# burica not found. Skipping...
# Processing Record 29 of Set 11 | skibbereen
# Processing Record 30 of Set 11 | filadelfia
# Processing Record 31 of Set 11 | lata
# Processing Record 32 of Set 11 | kinshasa
# Processing Record 33 of Set 11 | cabedelo
# Processing Record 34 of Set 11 | los llanos de aridane
# Processing Record 35 of Set 11 | garango
# Processing Record 36 of Set 11 | saint-augustin
# Processing Record 37 of Set 11 | elliot lake
# Processing Record 38 of Set 11 | banjar
# Processing Record 39 of Set 11 | mogadishu
# Processing Record 40 of Set 11 | sergeyevka
# Processing Record 41 of Set 11 | utiroa
# utiroa not found. Skipping...
# Processing Record 42 of Set 11 | merisani
# Processing Record 43 of Set 11 | kununurra
# Processing Record 44 of Set 11 | matara
# Processing Record 45 of Set 11 | ekhabi
# Processing Record 46 of Set 11 | esso
# Processing Record 47 of Set 11 | doha
# Processing Record 48 of Set 11 | emerald
# Processing Record 49 of Set 11 | tubli
# Processing Record 50 of Set 11 | marondera
# Processing Record 1 of Set 12 | penzance
# Processing Record 2 of Set 12 | souillac
# Processing Record 3 of Set 12 | jiroft
# jiroft not found. Skipping...
# Processing Record 4 of Set 12 | port lavaca
# Processing Record 5 of Set 12 | oranjemund
# Processing Record 6 of Set 12 | ligayan
# Processing Record 7 of Set 12 | asmara
# Processing Record 8 of Set 12 | ozgon
# ozgon not found. Skipping...
# Processing Record 9 of Set 12 | dunedin
# Processing Record 10 of Set 12 | chikoy
# chikoy not found. Skipping...
# Processing Record 11 of Set 12 | namatanai
# Processing Record 12 of Set 12 | gizo
# Processing Record 13 of Set 12 | thinadhoo
# Processing Record 14 of Set 12 | coquimbo
# Processing Record 15 of Set 12 | schwedt
# Processing Record 16 of Set 12 | mwense
# Processing Record 17 of Set 12 | rio grande
# Processing Record 18 of Set 12 | hambantota
# Processing Record 19 of Set 12 | teguise
# Processing Record 20 of Set 12 | horodkivka
# Processing Record 21 of Set 12 | spring hill
# Processing Record 22 of Set 12 | mbandaka
# Processing Record 23 of Set 12 | munster
# Processing Record 24 of Set 12 | smidovich
# Processing Record 25 of Set 12 | mehran
# Processing Record 26 of Set 12 | matsanga
# matsanga not found. Skipping...
# Processing Record 27 of Set 12 | kysyl-syr
# Processing Record 28 of Set 12 | great bend
# Processing Record 29 of Set 12 | teneguiban
# teneguiban not found. Skipping...
# Processing Record 30 of Set 12 | azimur
# azimur not found. Skipping...
# Processing Record 31 of Set 12 | darhan
# Processing Record 32 of Set 12 | berezovyy
# Processing Record 33 of Set 12 | erenhot
# Processing Record 34 of Set 12 | vaitape
# Processing Record 35 of Set 12 | hihifo
# hihifo not found. Skipping...
# Processing Record 36 of Set 12 | viedma
# Processing Record 37 of Set 12 | meyungs
# meyungs not found. Skipping...
# Processing Record 38 of Set 12 | maceio
# Processing Record 39 of Set 12 | sola
# Processing Record 40 of Set 12 | lulea
# Processing Record 41 of Set 12 | rorvik
# Processing Record 42 of Set 12 | providencia
# Processing Record 43 of Set 12 | burns lake
# Processing Record 44 of Set 12 | meulaboh
# Processing Record 45 of Set 12 | mingshui
# Processing Record 46 of Set 12 | sorvag
# sorvag not found. Skipping...
# Processing Record 47 of Set 12 | brigantine
# Processing Record 48 of Set 12 | soanierana ivongo
# Processing Record 49 of Set 12 | zhezkazgan
# Processing Record 50 of Set 12 | kalmunai
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 542

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Clouds   Wind  \
# 0          Kuching   1.5500  110.3333     80.82        83      20   6.91
# 1         Sattahip  12.6664  100.9007     82.49        78      40   5.75
# 2  Charters Towers -20.1000  146.2667     77.05        49      75  16.49
# 3            Bluff -46.6000  168.3333     44.80        68      90  19.80
# 4          Ushuaia -54.8000  -68.3000     37.06        81      20   0.00
# 5         La Plata -34.9215  -57.9545     58.77        96      11   4.94
# 6            Kapaa  22.0752 -159.3190     84.52        68      20   5.01
# 7            Vaini -21.2000 -175.2000     78.96        78      20   6.91
# 8           Yantai  37.5333  121.4000     78.62        73      10  11.18
# 9   Port Macquarie -31.4333  152.9167     78.76        40       0   8.79
#
#   Country                 Date
# 0      MY  2021-09-11 01:32:57
# 1      TH  2021-09-11 01:29:08
# 2      AU  2021-09-11 01:32:58
# 3      NZ  2021-09-11 01:32:58
# 4      AR  2021-09-11 01:30:44
# 5      AR  2021-09-11 01:30:03
# 6      US  2021-09-11 01:32:59
# 7      TO  2021-09-11 01:32:59
# 8      CN  2021-09-11 01:32:59
# 9      AU  2021-09-11 01:28:00

# %%
city_data_df = city_data_df[['City', 'Country', 'Date', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Clouds', 'Wind']]
city_data_df = city_data_df.rename(columns={'Clouds': 'Cloudiness', 'Wind': 'Wind Speed'})
city_data_df.head(10)
# Out:
#               City Country                 Date      Lat       Lng  Max Temp  \
# 0          Kuching      MY  2021-09-11 01:32:57   1.5500  110.3333     80.82
# 1         Sattahip      TH  2021-09-11 01:29:08  12.6664  100.9007     82.49
# 2  Charters Towers      AU  2021-09-11 01:32:58 -20.1000  146.2667     77.05
# 3            Bluff      NZ  2021-09-11 01:32:58 -46.6000  168.3333     44.80
# 4          Ushuaia      AR  2021-09-11 01:30:44 -54.8000  -68.3000     37.06
# 5         La Plata      AR  2021-09-11 01:30:03 -34.9215  -57.9545     58.77
# 6            Kapaa      US  2021-09-11 01:32:59  22.0752 -159.3190     84.52
# 7            Vaini      TO  2021-09-11 01:32:59 -21.2000 -175.2000     78.96
# 8           Yantai      CN  2021-09-11 01:32:59  37.5333  121.4000     78.62
# 9   Port Macquarie      AU  2021-09-11 01:28:00 -31.4333  152.9167     78.76
#
#    Humidity  Cloudiness  Wind Speed
# 0        83          20        6.91
# 1        78          40        5.75
# 2        49          75       16.49
# 3        68          90       19.80
# 4        81          20        0.00
# 5        96          11        4.94
# 6        68          20        5.01
# 7        78          20        6.91
# 8        73          10       11.18
# 9        40           0        8.79

# %%
# Create an output file (CSV)
file_to_save = 'weather_data/cities.csv'

# Export the city data into a CSV
city_data_df.to_csv(file_to_save, index_label='City_ID')

# %%
# Import dependency for visualizations
import time
plt.subplots(figsize=(10,6))
plt.scatter(x=city_data_df['Lat'], y=city_data_df['Max Temp'], 
            edgecolor='k', linewidths=1, marker='o', alpha=0.8, label='Cities'
            )
plt.title('City Latitude vs. Max Temperature ' + time.strftime('%x'))
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.savefig('weather_data/Fig1.png')
plt.grid()

# %%
plt.subplots(figsize=(10,6))
plt.scatter(x=city_data_df['Lat'], y=city_data_df['Humidity'], 
            edgecolor='k', linewidths=1, marker='o', alpha=0.8, label='Cities'
            )
plt.title('City Latitude vs. Humidity ' + time.strftime('%x'))
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.savefig('weather_data/Fig2.png')
plt.grid()

# %%
plt.subplots(figsize=(10,6))
plt.scatter(x=city_data_df['Lat'], y=city_data_df['Cloudiness'], 
            edgecolor='k', linewidths=1, marker='o', alpha=0.8, label='Cities'
            )
plt.title('City Latitude vs. Cloudiness ' + time.strftime('%x'))
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.savefig('weather_data/Fig3.png')
plt.grid()

# %%
plt.subplots(figsize=(10,6))
plt.scatter(x=city_data_df['Lat'], y=city_data_df['Wind Speed'], 
            edgecolor='k', linewidths=1, marker='o', alpha=0.8, label='Cities'
            )
plt.title('City Latitude vs. Wind Speed ' + time.strftime('%x'))
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.savefig('weather_data/Fig4.png')
plt.grid()

# %%
# import function dependency
from scipy.stats import linregress

# Create a function to perform linear regression on the weather data and plot a regression line and the equation with the data
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

    # Run regression on hemisphere weather data
    (m, b, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculation the regression line y-values
    regress_values = m * x_values + b

    # Get the equation of the line
    line_eq = 'y = '  + str(round(m, 2)) + 'x + ' + str(round(b, 2))

    # Create a scatter plot and plot the regression line
    plt.scatter(x_values, y_values)
    plt.plot(x_values, regress_values, 'r')
    plt.annotate(line_eq, text_coordinates, fontsize=15, c='r')
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.title(title)

# %%
northern_hemi_df = city_data_df.loc[city_data_df['Lat'] >= 0]
southern_hemi_df = city_data_df.loc[city_data_df['Lat'] < 0]

# %%
plot_linear_regression(northern_hemi_df['Lat'], northern_hemi_df['Max Temp'], 'Linear Regression on Northern Hemisphere \n for Maximum Temperature', 'Max Temperature (F)', (0, 20))

# %%
plot_linear_regression(southern_hemi_df['Lat'], southern_hemi_df['Max Temp'], 'Linear Regression on Southern Hemisphere \n for Maximum Temperature', 'Max Temperature (F)', (-55, 88))

# %%
plot_linear_regression(northern_hemi_df['Lat'], northern_hemi_df['Humidity'], 'Linear Regression on Northern Hemisphere \n for Humidity', 'Humidity (%)', (45, 17))

# %%
plot_linear_regression(southern_hemi_df['Lat'], southern_hemi_df['Humidity'], 'Linear Regression on Southern Hemisphere \n for Humidity', 'Humidity (%)', (-55, 15))

# %%
plot_linear_regression(northern_hemi_df['Lat'], northern_hemi_df['Cloudiness'], 'Linear Regression on Northern Hemisphere \n for Cloudiness', 'Cloudiness (%)', (0, 45))

# %%
plot_linear_regression(southern_hemi_df['Lat'], southern_hemi_df['Cloudiness'], 'Linear Regression on Southern Hemisphere \n for Cloudiness', 'Cloudiness (%)', (-42, 25))

# %%
plot_linear_regression(northern_hemi_df['Lat'], northern_hemi_df['Wind Speed'], 'Linear Regression on Northern Hemisphere \n for Wind Speed', 'Wind Speed (mph)', (48, 41))

# %%
plot_linear_regression(southern_hemi_df['Lat'], southern_hemi_df['Wind Speed'], 'Linear Regression on Southern Hemisphere \n for Wind Speed', 'Wind Speed (mph)', (-53, 0))
